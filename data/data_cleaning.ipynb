# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel('data.xlsx')

# %%
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  compressionratio  \
# 0  convertible        rwd          front       88.6  ...               9.0
# 1  convertible        rwd          front       88.6  ...               9.0
# 2    hatchback        rwd          front       94.5  ...               9.0
# 3        sedan        fwd          front       99.8  ...              10.0
# 4        sedan        4wd          front       99.4  ...               8.0
#
#    horsepower  peakrpm  citympg highwaympg    price  sales 2018 sales 2019  \
# 0         111     5000       21         27  13495.0     34300.0    18294.0
# 1         111     5000       21         27  16500.0     12043.0     9444.0
# 2         154     5000       19         26  16500.0     17075.0    10932.0
# 3         102     5500       24         30  13950.0         0.0        0.0
# 4         115     5500       18         22  17450.0         0.0        0.0
#
#    sales 2020  sales 2021
# 0     17200.0     18252.0
# 1     10282.0     10539.0
# 2      7436.0      6297.0
# 3         0.0         0.0
# 4         0.0         0.0
#
# [5 rows x 30 columns]

# %%
df.tail()
# Out:
#      car_ID  symboling          CarName fueltype aspiration doornumber  \
# 200     201         -1  volvo 145e (sw)      gas        std       four
# 201     202         -1      volvo 144ea      gas      turbo       four
# 202     203         -1      volvo 244dl      gas        std       four
# 203     204         -1        volvo 246   diesel      turbo       four
# 204     205         -1      volvo 264gl      gas      turbo       four
#
#     carbody drivewheel enginelocation  wheelbase  ...  compressionratio  \
# 200   sedan        rwd          front      109.1  ...               9.5
# 201   sedan        rwd          front      109.1  ...               8.7
# 202   sedan        rwd          front      109.1  ...               8.8
# 203   sedan        rwd          front      109.1  ...              23.0
# 204   sedan        rwd          front      109.1  ...               9.5
#
#      horsepower  peakrpm  citympg highwaympg    price  sales 2018 sales 2019  \
# 200         114     5400       23         28  16845.0         0.0        0.0
# 201         160     5300       19         25  19045.0         0.0        0.0
# 202         134     5500       18         23  21485.0         0.0        0.0
# 203         106     4800       26         27  22470.0         0.0        0.0
# 204         114     5400       19         25  22625.0         0.0        0.0
#
#      sales 2020  sales 2021
# 200         0.0         0.0
# 201         0.0         0.0
# 202         0.0         0.0
# 203         0.0         0.0
# 204         0.0         0.0
#
# [5 rows x 30 columns]

# %%
li = []
for i in range(205):
    li.append(df.iat[i, 26] + df.iat[i, 27] + df.iat[i, 28] + df.iat[i, 29])
df['total_sales'] = li

# %%
df
# Out:
#      car_ID  symboling                   CarName fueltype aspiration  \
# 0         1          3        alfa-romero giulia      gas        std
# 1         2          3       alfa-romero stelvio      gas        std
# 2         3          1  alfa-romero Quadrifoglio      gas        std
# 3         4          2               audi 100 ls      gas        std
# 4         5          2                audi 100ls      gas        std
# ..      ...        ...                       ...      ...        ...
# 200     201         -1           volvo 145e (sw)      gas        std
# 201     202         -1               volvo 144ea      gas      turbo
# 202     203         -1               volvo 244dl      gas        std
# 203     204         -1                 volvo 246   diesel      turbo
# 204     205         -1               volvo 264gl      gas      turbo
#
#     doornumber      carbody drivewheel enginelocation  wheelbase  ...  \
# 0          two  convertible        rwd          front       88.6  ...
# 1          two  convertible        rwd          front       88.6  ...
# 2          two    hatchback        rwd          front       94.5  ...
# 3         four        sedan        fwd          front       99.8  ...
# 4         four        sedan        4wd          front       99.4  ...
# ..         ...          ...        ...            ...        ...  ...
# 200       four        sedan        rwd          front      109.1  ...
# 201       four        sedan        rwd          front      109.1  ...
# 202       four        sedan        rwd          front      109.1  ...
# 203       four        sedan        rwd          front      109.1  ...
# 204       four        sedan        rwd          front      109.1  ...
#
#      horsepower  peakrpm  citympg  highwaympg    price sales 2018  sales 2019  \
# 0           111     5000       21          27  13495.0    34300.0     18294.0
# 1           111     5000       21          27  16500.0    12043.0      9444.0
# 2           154     5000       19          26  16500.0    17075.0     10932.0
# 3           102     5500       24          30  13950.0        0.0         0.0
# 4           115     5500       18          22  17450.0        0.0         0.0
# ..          ...      ...      ...         ...      ...        ...         ...
# 200         114     5400       23          28  16845.0        0.0         0.0
# 201         160     5300       19          25  19045.0        0.0         0.0
# 202         134     5500       18          23  21485.0        0.0         0.0
# 203         106     4800       26          27  22470.0        0.0         0.0
# 204         114     5400       19          25  22625.0        0.0         0.0
#
#     sales 2020  sales 2021  total_sales
# 0      17200.0     18252.0      88046.0
# 1      10282.0     10539.0      42308.0
# 2       7436.0      6297.0      41740.0
# 3          0.0         0.0          0.0
# 4          0.0         0.0          0.0
# ..         ...         ...          ...
# 200        0.0         0.0          0.0
# 201        0.0         0.0          0.0
# 202        0.0         0.0          0.0
# 203        0.0         0.0          0.0
# 204        0.0         0.0          0.0
#
# [205 rows x 31 columns]

# %%
df.to_excel('data.xlsx')
